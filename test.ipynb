# %%
dict = {1: 'hi'}

print(dict.get(2))
# Out:
# None

# %%
text = "     "

if text:
    print('hi')
else:
    print('here')
# Out:
# hi

# %%
if None:
    print('hi')
else:
    print('2')
# Out:
# 2

# %%
import pandas as pd
len(pd.DataFrame())
# Out:
# 0

# %%
import uuid

random_id = uuid.uuid4().hex
random_id
# Out:
# '28f544273f444159b39ca25d262b5c2f'

# %%
import hashlib

def file_hash(file):
    return hashlib.sha256(file.getvalue()).hexdigest()

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\alfonso.kan_globe\\Desktop\\projects\\isdp_ocr'

# %%
import hashlib

def file_hash_from_path(path, chunk_size=8192):
    sha = hashlib.sha256()
    with open(path, "rb") as f:
        for chunk in iter(lambda: f.read(chunk_size), b""):
            sha.update(chunk)
    return sha.hexdigest()


file_hash_from_path("sms_screenshot/image_1.png")
# Out:
# '263fe0c6de01cce014b101a3476551a6c04b7326406f09bd4d6f0d9a81a0bf0a'

# %%
def convert_bytes_to_hash(file):
    sha = hashlib.sha256()

    # read file as bytes
    file_bytes = file.getvalue()

    sha.update(file_bytes)

    return sha.hexdigest()

# %%
doc_id_to_metadata = {
    "6a34e41ca4eb466c92242eabed1392ec":{
        "idx":0,
        "file_hash":"043f09ff79cc9564d17972ce70175ed92eccb30b46d277d557c8142ac16bda9d",
        "file_name":"4.png"
    },

    "gg10":{
        "idx": 1,
        "file_hash":"235",
        "file_name":"5.png"
    }

}

uploaded_files = [1,2,3]


for uuid, file in zip(doc_id_to_metadata.keys(), uploaded_files):
    idx = doc_id_to_metadata[uuid]['idx']
    
    print(idx, uuid, file)
# Out:
# 0 6a34e41ca4eb466c92242eabed1392ec 1
# 1 gg10 2
