# %%
dict = {1: 'hi'}

print(dict.get(2))
# Out:
# None

# %%
text = "     "

if text:
    print('hi')
else:
    print('here')
# Out:
# hi

# %%
if None:
    print('hi')
else:
    print('2')
# Out:
# 2

# %%
import pandas as pd
len(pd.DataFrame())
# Out:
# 0
